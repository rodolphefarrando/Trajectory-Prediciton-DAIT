# %%
import torch
from torch import nn
from torch.autograd import Variable
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from LSTM import *
from LSTMbis import *
import pandas as pd
import numpy as np
import torch.utils.data as utils
import time

import pdb

torch.manual_seed(1)

# %%
import os
data = {}
a=0
for j in range(1,7):
    for i in os.listdir('./new_data/%s'%j):
        if i.endswith('.txt'):
            a = a+1
            data['%s'%a] = pd.read_csv('new_data/{}/{}'.format(j,i), header = None, 
                                        names = ['frameNb','id', 'x','y','Vx','Vy'],
                                           delimiter=' ')

# %%
a = 0
inputs = np.zeros([10,len(data),2])
gt = np.zeros([11,len(data),2])
in_coord = np.zeros([10,len(data),2])
gt_coord = np.zeros([11,len(data),2])

for i in data:
    inputs[:,a,:] = np.array(data['%s'%i].loc[0:9,['Vx','Vy']])
    gt[:,a,:] = np.array(data['%s'%i].loc[9:19,['Vx','Vy']])
    in_coord[:,a,:] = np.array(data['%s'%i].loc[0:9,['x','y']])
    gt_coord[:,a,:] = np.array(data['%s'%i].loc[9:19,['x','y']])
    a +=1


inputs = torch.from_numpy(inputs).float()
gt = torch.from_numpy(gt).float()
inputs = inputs.permute([1,0,2])
gt = gt.permute([1,0,2])

# %%
from torch import optim

lstm = LSTM(2)
optimizer = optim.SGD(lstm.parameters(), lr=0.05)
criterion = nn.MSELoss()

# %%
traindataset = utils.TensorDataset(inputs, gt[:,1:,:])
trainloader = utils.DataLoader(traindataset, batch_size=2, shuffle=True)

epochs = 20
steps = 0
print_every = 100
running_loss = 0 #### DOD

for e in range(epochs):
    start = time.time()
    for train_coord, ground_tru in iter(trainloader):
        steps += 1
        
        train_coord = train_coord.permute([1,0,2])
        ground_tru = ground_tru.permute([1,0,2])

        in_train = Variable(train_coord)
        targets = Variable(ground_tru)
        optimizer.zero_grad()
        #print(in_train.shape)
        #print(targets.shape)
        #pdb.set_trace()
        out = lstm.forward(in_train)
        loss = criterion(out, targets)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.data[0]

    
        if steps % print_every == 0:
                stop = time.time()
                print("Epoch: {}/{}..".format(e+1, epochs),
                  "Loss: {:.4f}..".format(running_loss/print_every),
                  "{:.4f} s/batch".format((stop - start)/print_every)
                 )
                running_loss = 0
                start = time.time()
# Out:
# /Users/rodolphefarrando/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# Epoch: 1/20.. Loss: 0.1942.. 0.0024 s/batch
# Epoch: 1/20.. Loss: 0.1891.. 0.0021 s/batch
# Epoch: 1/20.. Loss: 0.1698.. 0.0019 s/batch
# Epoch: 1/20.. Loss: 0.1470.. 0.0038 s/batch
# Epoch: 1/20.. Loss: 0.1540.. 0.0036 s/batch
# Epoch: 1/20.. Loss: 0.1377.. 0.0017 s/batch
# Epoch: 1/20.. Loss: 0.1501.. 0.0020 s/batch
# Epoch: 1/20.. Loss: 0.1393.. 0.0017 s/batch
# Epoch: 1/20.. Loss: 0.1336.. 0.0021 s/batch
# Epoch: 1/20.. Loss: 0.1151.. 0.0020 s/batch
# Epoch: 1/20.. Loss: 0.1259.. 0.0021 s/batch
# Epoch: 1/20.. Loss: 0.1408.. 0.0018 s/batch
# Epoch: 2/20.. Loss: 0.1294.. 0.0016 s/batch
# Epoch: 2/20.. Loss: 0.1487.. 0.0017 s/batch
# Epoch: 2/20.. Loss: 0.1261.. 0.0021 s/batch
# Epoch: 2/20.. Loss: 0.1312.. 0.0020 s/batch
# Epoch: 2/20.. Loss: 0.1311.. 0.0022 s/batch
# Epoch: 2/20.. Loss: 0.1245.. 0.0019 s/batch
# Epoch: 2/20.. Loss: 0.1281.. 0.0046 s/batch
# Epoch: 2/20.. Loss: 0.1149.. 0.0034 s/batch
# Epoch: 2/20.. Loss: 0.1197.. 0.0017 s/batch
# Epoch: 2/20.. Loss: 0.1382.. 0.0020 s/batch
# Epoch: 2/20.. Loss: 0.1170.. 0.0018 s/batch
# Epoch: 2/20.. Loss: 0.1412.. 0.0019 s/batch
# Epoch: 3/20.. Loss: 0.1342.. 0.0006 s/batch
# Epoch: 3/20.. Loss: 0.1307.. 0.0020 s/batch
# Epoch: 3/20.. Loss: 0.1109.. 0.0017 s/batch
# Epoch: 3/20.. Loss: 0.1377.. 0.0020 s/batch
# Epoch: 3/20.. Loss: 0.1291.. 0.0018 s/batch
# Epoch: 3/20.. Loss: 0.1141.. 0.0020 s/batch
# Epoch: 3/20.. Loss: 0.1408.. 0.0018 s/batch
# Epoch: 3/20.. Loss: 0.1312.. 0.0020 s/batch
# Epoch: 3/20.. Loss: 0.1238.. 0.0017 s/batch
# Epoch: 3/20.. Loss: 0.1140.. 0.0019 s/batch
# Epoch: 3/20.. Loss: 0.1261.. 0.0017 s/batch
# Epoch: 3/20.. Loss: 0.1200.. 0.0019 s/batch
# Epoch: 4/20.. Loss: 0.1167.. 0.0001 s/batch
# Epoch: 4/20.. Loss: 0.1167.. 0.0018 s/batch
# Epoch: 4/20.. Loss: 0.1223.. 0.0021 s/batch
# Epoch: 4/20.. Loss: 0.1201.. 0.0021 s/batch
# Epoch: 4/20.. Loss: 0.1267.. 0.0020 s/batch
# Epoch: 4/20.. Loss: 0.1319.. 0.0021 s/batch
# Epoch: 4/20.. Loss: 0.1209.. 0.0018 s/batch
# Epoch: 4/20.. Loss: 0.1116.. 0.0020 s/batch
# Epoch: 4/20.. Loss: 0.1368.. 0.0017 s/batch
# Epoch: 4/20.. Loss: 0.1318.. 0.0019 s/batch
# Epoch: 4/20.. Loss: 0.1189.. 0.0028 s/batch
# Epoch: 4/20.. Loss: 0.1149.. 0.0016 s/batch
# Epoch: 4/20.. Loss: 0.1042.. 0.0019 s/batch
# Epoch: 5/20.. Loss: 0.1023.. 0.0011 s/batch
# Epoch: 5/20.. Loss: 0.1274.. 0.0019 s/batch
# Epoch: 5/20.. Loss: 0.1258.. 0.0018 s/batch
# Epoch: 5/20.. Loss: 0.1360.. 0.0020 s/batch
# Epoch: 5/20.. Loss: 0.1041.. 0.0017 s/batch
# Epoch: 5/20.. Loss: 0.1136.. 0.0019 s/batch
# Epoch: 5/20.. Loss: 0.1271.. 0.0017 s/batch
# Epoch: 5/20.. Loss: 0.1360.. 0.0020 s/batch
# Epoch: 5/20.. Loss: 0.1137.. 0.0017 s/batch
# Epoch: 5/20.. Loss: 0.1041.. 0.0020 s/batch
# Epoch: 5/20.. Loss: 0.1287.. 0.0017 s/batch
# Epoch: 5/20.. Loss: 0.1176.. 0.0020 s/batch
# Epoch: 6/20.. Loss: 0.1190.. 0.0007 s/batch
# Epoch: 6/20.. Loss: 0.1041.. 0.0020 s/batch
# Epoch: 6/20.. Loss: 0.1262.. 0.0018 s/batch
# Epoch: 6/20.. Loss: 0.1194.. 0.0020 s/batch
# Epoch: 6/20.. Loss: 0.1139.. 0.0017 s/batch
# Epoch: 6/20.. Loss: 0.1335.. 0.0019 s/batch
# Epoch: 6/20.. Loss: 0.1220.. 0.0016 s/batch
# Epoch: 6/20.. Loss: 0.1247.. 0.0020 s/batch
# Epoch: 6/20.. Loss: 0.1197.. 0.0017 s/batch
# Epoch: 6/20.. Loss: 0.1050.. 0.0020 s/batch
# Epoch: 6/20.. Loss: 0.1092.. 0.0017 s/batch
# Epoch: 6/20.. Loss: 0.1255.. 0.0020 s/batch
# Epoch: 7/20.. Loss: 0.1132.. 0.0001 s/batch
# Epoch: 7/20.. Loss: 0.1229.. 0.0020 s/batch
# Epoch: 7/20.. Loss: 0.1198.. 0.0018 s/batch
# Epoch: 7/20.. Loss: 0.1110.. 0.0019 s/batch
# Epoch: 7/20.. Loss: 0.1007.. 0.0015 s/batch
# Epoch: 7/20.. Loss: 0.1209.. 0.0020 s/batch
# Epoch: 7/20.. Loss: 0.1269.. 0.0016 s/batch
# Epoch: 7/20.. Loss: 0.1102.. 0.0020 s/batch
# Epoch: 7/20.. Loss: 0.1092.. 0.0016 s/batch
# Epoch: 7/20.. Loss: 0.1071.. 0.0020 s/batch
# Epoch: 7/20.. Loss: 0.1292.. 0.0017 s/batch
# Epoch: 7/20.. Loss: 0.1163.. 0.0020 s/batch
# Epoch: 7/20.. Loss: 0.1379.. 0.0018 s/batch
# Epoch: 8/20.. Loss: 0.1339.. 0.0015 s/batch
# Epoch: 8/20.. Loss: 0.1340.. 0.0018 s/batch
# Epoch: 8/20.. Loss: 0.1036.. 0.0020 s/batch
# Epoch: 8/20.. Loss: 0.0998.. 0.0022 s/batch
# Epoch: 8/20.. Loss: 0.1184.. 0.0021 s/batch
# Epoch: 8/20.. Loss: 0.1050.. 0.0020 s/batch
# Epoch: 8/20.. Loss: 0.1245.. 0.0020 s/batch
# Epoch: 8/20.. Loss: 0.1067.. 0.0017 s/batch
# Epoch: 8/20.. Loss: 0.1178.. 0.0020 s/batch
# Epoch: 8/20.. Loss: 0.1100.. 0.0017 s/batch
# Epoch: 8/20.. Loss: 0.1288.. 0.0023 s/batch
# Epoch: 8/20.. Loss: 0.1286.. 0.0023 s/batch
# Epoch: 9/20.. Loss: 0.1317.. 0.0007 s/batch
# Epoch: 9/20.. Loss: 0.1223.. 0.0026 s/batch
# Epoch: 9/20.. Loss: 0.1178.. 0.0031 s/batch
# Epoch: 9/20.. Loss: 0.1333.. 0.0019 s/batch
# Epoch: 9/20.. Loss: 0.1230.. 0.0045 s/batch
# Epoch: 9/20.. Loss: 0.1210.. 0.0057 s/batch
# Epoch: 9/20.. Loss: 0.1212.. 0.0048 s/batch
# Epoch: 9/20.. Loss: 0.1048.. 0.0043 s/batch
# Epoch: 9/20.. Loss: 0.1162.. 0.0032 s/batch
# Epoch: 9/20.. Loss: 0.1046.. 0.0018 s/batch
# Epoch: 9/20.. Loss: 0.1127.. 0.0023 s/batch
# Epoch: 9/20.. Loss: 0.1161.. 0.0019 s/batch
# Epoch: 10/20.. Loss: 0.1074.. 0.0002 s/batch
# Epoch: 10/20.. Loss: 0.1275.. 0.0019 s/batch
# Epoch: 10/20.. Loss: 0.1326.. 0.0021 s/batch
# Epoch: 10/20.. Loss: 0.1003.. 0.0018 s/batch
# Epoch: 10/20.. Loss: 0.1046.. 0.0021 s/batch
# Epoch: 10/20.. Loss: 0.1124.. 0.0019 s/batch
# Epoch: 10/20.. Loss: 0.1293.. 0.0021 s/batch
# Epoch: 10/20.. Loss: 0.1277.. 0.0017 s/batch
# Epoch: 10/20.. Loss: 0.1120.. 0.0020 s/batch
# Epoch: 10/20.. Loss: 0.1251.. 0.0017 s/batch
# Epoch: 10/20.. Loss: 0.1107.. 0.0020 s/batch
# Epoch: 10/20.. Loss: 0.1078.. 0.0019 s/batch
# Epoch: 10/20.. Loss: 0.1230.. 0.0020 s/batch
# Epoch: 11/20.. Loss: 0.1131.. 0.0013 s/batch
# Epoch: 11/20.. Loss: 0.1260.. 0.0021 s/batch
# Epoch: 11/20.. Loss: 0.1202.. 0.0017 s/batch
# Epoch: 11/20.. Loss: 0.1239.. 0.0021 s/batch
# Epoch: 11/20.. Loss: 0.1132.. 0.0017 s/batch
# Epoch: 11/20.. Loss: 0.1229.. 0.0021 s/batch
# Epoch: 11/20.. Loss: 0.1132.. 0.0019 s/batch
# Epoch: 11/20.. Loss: 0.1120.. 0.0039 s/batch
# Epoch: 11/20.. Loss: 0.1156.. 0.0031 s/batch
# Epoch: 11/20.. Loss: 0.1230.. 0.0018 s/batch
# Epoch: 11/20.. Loss: 0.1334.. 0.0021 s/batch
# Epoch: 11/20.. Loss: 0.1080.. 0.0018 s/batch
# Epoch: 12/20.. Loss: 0.1017.. 0.0009 s/batch
# Epoch: 12/20.. Loss: 0.1270.. 0.0019 s/batch
# Epoch: 12/20.. Loss: 0.0992.. 0.0045 s/batch
# Epoch: 12/20.. Loss: 0.1206.. 0.0040 s/batch
# Epoch: 12/20.. Loss: 0.1082.. 0.0019 s/batch
# Epoch: 12/20.. Loss: 0.1153.. 0.0024 s/batch
# Epoch: 12/20.. Loss: 0.1186.. 0.0018 s/batch
# Epoch: 12/20.. Loss: 0.1417.. 0.0022 s/batch
# Epoch: 12/20.. Loss: 0.1207.. 0.0019 s/batch
# Epoch: 12/20.. Loss: 0.1170.. 0.0024 s/batch
# Epoch: 12/20.. Loss: 0.1042.. 0.0041 s/batch
# Epoch: 12/20.. Loss: 0.1257.. 0.0018 s/batch
# Epoch: 13/20.. Loss: 0.1188.. 0.0003 s/batch
# Epoch: 13/20.. Loss: 0.0958.. 0.0019 s/batch
# Epoch: 13/20.. Loss: 0.1145.. 0.0022 s/batch
# Epoch: 13/20.. Loss: 0.1008.. 0.0019 s/batch
# Epoch: 13/20.. Loss: 0.1432.. 0.0022 s/batch
# Epoch: 13/20.. Loss: 0.1181.. 0.0041 s/batch
# Epoch: 13/20.. Loss: 0.1206.. 0.0017 s/batch
# Epoch: 13/20.. Loss: 0.1292.. 0.0021 s/batch
# Epoch: 13/20.. Loss: 0.0987.. 0.0017 s/batch
# Epoch: 13/20.. Loss: 0.1189.. 0.0022 s/batch
# Epoch: 13/20.. Loss: 0.1218.. 0.0019 s/batch
# Epoch: 13/20.. Loss: 0.1302.. 0.0038 s/batch
# Epoch: 13/20.. Loss: 0.1218.. 0.0033 s/batch
# Epoch: 14/20.. Loss: 0.1069.. 0.0015 s/batch
# Epoch: 14/20.. Loss: 0.1388.. 0.0021 s/batch
# Epoch: 14/20.. Loss: 0.0921.. 0.0019 s/batch
# Epoch: 14/20.. Loss: 0.1032.. 0.0022 s/batch
# Epoch: 14/20.. Loss: 0.1196.. 0.0037 s/batch
# Epoch: 14/20.. Loss: 0.1057.. 0.0032 s/batch
# Epoch: 14/20.. Loss: 0.1083.. 0.0018 s/batch
# Epoch: 14/20.. Loss: 0.1256.. 0.0023 s/batch
# Epoch: 14/20.. Loss: 0.1309.. 0.0019 s/batch
# Epoch: 14/20.. Loss: 0.1344.. 0.0022 s/batch
# Epoch: 14/20.. Loss: 0.1121.. 0.0018 s/batch
# Epoch: 14/20.. Loss: 0.1220.. 0.0022 s/batch
# Epoch: 15/20.. Loss: 0.1192.. 0.0010 s/batch
# Epoch: 15/20.. Loss: 0.1271.. 0.0022 s/batch
# Epoch: 15/20.. Loss: 0.1312.. 0.0019 s/batch
# Epoch: 15/20.. Loss: 0.1219.. 0.0022 s/batch
# Epoch: 15/20.. Loss: 0.1080.. 0.0021 s/batch
# Epoch: 15/20.. Loss: 0.1215.. 0.0022 s/batch
# Epoch: 15/20.. Loss: 0.1048.. 0.0020 s/batch
# Epoch: 15/20.. Loss: 0.1014.. 0.0021 s/batch
# Epoch: 15/20.. Loss: 0.1171.. 0.0020 s/batch
# Epoch: 15/20.. Loss: 0.1251.. 0.0022 s/batch
# Epoch: 15/20.. Loss: 0.1094.. 0.0020 s/batch
# Epoch: 15/20.. Loss: 0.1189.. 0.0020 s/batch
# Epoch: 16/20.. Loss: 0.1314.. 0.0004 s/batch
# Epoch: 16/20.. Loss: 0.1093.. 0.0020 s/batch
# Epoch: 16/20.. Loss: 0.1280.. 0.0016 s/batch
# Epoch: 16/20.. Loss: 0.1269.. 0.0031 s/batch
# Epoch: 16/20.. Loss: 0.1056.. 0.0028 s/batch
# Epoch: 16/20.. Loss: 0.1319.. 0.0020 s/batch
# Epoch: 16/20.. Loss: 0.1127.. 0.0030 s/batch
# Epoch: 16/20.. Loss: 0.1243.. 0.0016 s/batch
# Epoch: 16/20.. Loss: 0.1178.. 0.0023 s/batch
# Epoch: 16/20.. Loss: 0.1018.. 0.0017 s/batch
# Epoch: 16/20.. Loss: 0.1090.. 0.0020 s/batch
# Epoch: 16/20.. Loss: 0.1161.. 0.0017 s/batch
# Epoch: 16/20.. Loss: 0.1199.. 0.0021 s/batch
# Epoch: 17/20.. Loss: 0.1157.. 0.0016 s/batch
# Epoch: 17/20.. Loss: 0.1212.. 0.0021 s/batch
# Epoch: 17/20.. Loss: 0.1134.. 0.0018 s/batch
# Epoch: 17/20.. Loss: 0.1224.. 0.0021 s/batch
# Epoch: 17/20.. Loss: 0.1182.. 0.0018 s/batch
# Epoch: 17/20.. Loss: 0.1131.. 0.0021 s/batch
# Epoch: 17/20.. Loss: 0.1179.. 0.0018 s/batch
# Epoch: 17/20.. Loss: 0.1111.. 0.0021 s/batch
# Epoch: 17/20.. Loss: 0.1048.. 0.0018 s/batch
# Epoch: 17/20.. Loss: 0.1220.. 0.0021 s/batch
# Epoch: 17/20.. Loss: 0.1246.. 0.0018 s/batch
# Epoch: 17/20.. Loss: 0.1147.. 0.0021 s/batch
# Epoch: 18/20.. Loss: 0.1213.. 0.0010 s/batch
# Epoch: 18/20.. Loss: 0.1106.. 0.0021 s/batch
# Epoch: 18/20.. Loss: 0.1183.. 0.0021 s/batch
# Epoch: 18/20.. Loss: 0.1121.. 0.0023 s/batch
# Epoch: 18/20.. Loss: 0.1294.. 0.0020 s/batch
# Epoch: 18/20.. Loss: 0.1058.. 0.0020 s/batch
# Epoch: 18/20.. Loss: 0.0984.. 0.0018 s/batch
# Epoch: 18/20.. Loss: 0.1044.. 0.0021 s/batch
# Epoch: 18/20.. Loss: 0.1397.. 0.0018 s/batch
# Epoch: 18/20.. Loss: 0.1318.. 0.0021 s/batch
# Epoch: 18/20.. Loss: 0.1219.. 0.0018 s/batch
# Epoch: 18/20.. Loss: 0.1068.. 0.0020 s/batch
# Epoch: 19/20.. Loss: 0.1325.. 0.0005 s/batch
# Epoch: 19/20.. Loss: 0.1155.. 0.0020 s/batch
# Epoch: 19/20.. Loss: 0.1300.. 0.0018 s/batch
# Epoch: 19/20.. Loss: 0.1192.. 0.0020 s/batch
# Epoch: 19/20.. Loss: 0.1068.. 0.0016 s/batch
# Epoch: 19/20.. Loss: 0.1094.. 0.0019 s/batch
# Epoch: 19/20.. Loss: 0.1129.. 0.0017 s/batch
# Epoch: 19/20.. Loss: 0.1170.. 0.0021 s/batch
# Epoch: 19/20.. Loss: 0.1180.. 0.0018 s/batch
# Epoch: 19/20.. Loss: 0.1208.. 0.0020 s/batch
# Epoch: 19/20.. Loss: 0.1202.. 0.0018 s/batch
# Epoch: 19/20.. Loss: 0.1157.. 0.0020 s/batch
# Epoch: 19/20.. Loss: 0.1112.. 0.0018 s/batch
# Epoch: 20/20.. Loss: 0.1204.. 0.0019 s/batch
# Epoch: 20/20.. Loss: 0.1193.. 0.0016 s/batch
# Epoch: 20/20.. Loss: 0.1326.. 0.0020 s/batch
# Epoch: 20/20.. Loss: 0.1142.. 0.0017 s/batch
# Epoch: 20/20.. Loss: 0.1129.. 0.0021 s/batch
# Epoch: 20/20.. Loss: 0.1220.. 0.0018 s/batch
# Epoch: 20/20.. Loss: 0.1077.. 0.0022 s/batch
# Epoch: 20/20.. Loss: 0.1027.. 0.0017 s/batch
# Epoch: 20/20.. Loss: 0.1206.. 0.0019 s/batch
# Epoch: 20/20.. Loss: 0.1023.. 0.0016 s/batch
# Epoch: 20/20.. Loss: 0.1093.. 0.0020 s/batch
# Epoch: 20/20.. Loss: 0.1312.. 0.0016 s/batch

# %%
inputs = inputs.permute([1,0,2])
output_final = lstm.predict(inputs)
output_final = output_final.data.numpy()

# %% [markdown]
# ## Post processing step
# Go back to coordinate:
# We have Vx and Vy and we want x and y.
# $ V = d/t$
# $ d = V*t$
# Here t = 0.4s between each point.
# Start from data at index 9. Then we add d_x and d_y to the last x and y.

# %%
output_coord=np.zeros([11,len(data),2])
for j in range(11):
    for i in range(len(data)):
        if j==0:
            output_coord[j,i,:] = in_coord[9,i,:]
        else:
            output_coord[j,i,:] = output_coord[j-1,i,:]+output_final[j-1,i,:]*0.4

# %%
for i in range(20):
    plt.figure(figsize=(12, 7))

    plt.plot(in_coord[:,i*20,0],in_coord[:,i*20,1],c='b')
    plt.plot(gt_coord[:,i*20,0],gt_coord[:,i*20,1],c='k')
    plt.plot(output_coord[:,i*20,0],output_coord[:,i*20,1],c='r')
    plt.axis('equal')

# %%
sum(sum(output_final>1))

# %%
np.sum(output_final>1,axis=1)

# %%
len(data)
# Out:
# 2463

# %%
inputs.shape
# Out:
# torch.Size([2463, 10, 2])
