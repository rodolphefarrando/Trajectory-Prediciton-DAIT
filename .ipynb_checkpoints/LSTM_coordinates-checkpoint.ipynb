# %%
import torch
from torch import nn
from torch.autograd import Variable
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from LSTM import *
from LSTMbis import *
import pandas as pd
import numpy as np
import torch.utils.data as utils
import time
import os

import pdb

# For the notebook
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

torch.manual_seed(1)

# %%
data_train = {}
data_val = {}
data_test = {}
a = 0
b = 0
c = 0
max_len = 0
for j in range(1,4):
    for i in os.listdir('./final_dataset/train/%s'%j):
        if i.endswith('.txt'):
            a = a+1
            data_train['%s'%a] = pd.read_csv('./final_dataset/train/{}/{}'.format(j,i), header = None, 
                                        names = ['frameNb','id', 'x','y','Vx','Vy'],
                                           delimiter=' ')
            if len(data_train['%s'%a])/20>max_len:
                max_len=int(len(data_train['%s'%a])/20)
    for i in os.listdir('./final_dataset/validation/%s'%j):
        if i.endswith('.txt'):
            b = b+1
            data_val['%s'%b] = pd.read_csv('./final_dataset/validation/{}/{}'.format(j,i), header = None, 
                                        names = ['frameNb','id', 'x','y','Vx','Vy'],
                                           delimiter=' ') 
    for i in os.listdir('./final_dataset/test/%s'%j):
        if i.endswith('.txt'):
            c = c+1
            data_test['%s'%c] = pd.read_csv('./final_dataset/test/{}/{}'.format(j,i), header = None, 
                                        names = ['frameNb','id', 'x','y','Vx','Vy'],
                                           delimiter=' ')

# %%
max_len
# Out:
# 68

# %% [markdown]
# ## TRAIN SET

# %%
a = 0
inputs_train = np.zeros([10,len(data_train),4*max_len])
gt_train = np.zeros([11,len(data_train),4])
in_train_coord = np.zeros([10,len(data_train),2])
gt_train_coord = np.zeros([11,len(data_train),2])

for i in data_train:
    len_d = np.int(len(data_train['%s'%i])/20)
    inputs_train[:,a,:4] = data_train['%s'%i].loc[0:9,'x':'Vy']
    for m in range(10):
        frame = np.array(data_train['%s'%i].loc[m,'frameNb'])  
        for j in range(1,len_d):
            for k in range(20):
                if data_train['%s'%i].loc[j*20+k,'frameNb']==frame:
                    inputs_train[m,a,j*4:(j+1)*4]=data_train['%s'%i].loc[j*20+k,'x':'Vy']
    
    gt_train[:,a,:] = np.array(data_train['%s'%i].loc[9:19,['x','y','Vx','Vy']])
    in_train_coord[:,a,:] = np.array(data_train['%s'%i].loc[0:9,['x','y']])
    gt_train_coord[:,a,:] = np.array(data_train['%s'%i].loc[9:19,['x','y']])
    a +=1


inputs_train = torch.from_numpy(inputs_train).float()
gt_train = torch.from_numpy(gt_train).float()
inputs_train = inputs_train.permute([1,0,2])
gt_train = gt_train.permute([1,0,2])

# %% [markdown]
# ## VALIDATION SET

# %%
a = 0
inputs_validation = np.zeros([10,len(data_val),4*max_len])
gt_validation = np.zeros([11,len(data_val),4])
in_validation_coord = np.zeros([10,len(data_val),2])
gt_validation_coord = np.zeros([11,len(data_val),2])

for i in data_val:
    len_d = np.int(len(data_val['%s'%i])/20)
    inputs_validation[:,a,:4] = data_val['%s'%i].loc[0:9,'x':'Vy']
    for m in range(10):
        frame = np.array(data_val['%s'%i].loc[m,'frameNb'])  
        for j in range(1,len_d):
            for k in range(20):
                if data_val['%s'%i].loc[j*20+k,'frameNb']==frame:
                    inputs_validation[m,a,j*4:(j+1)*4]=data_val['%s'%i].loc[j*20+k,'x':'Vy']
    
    gt_validation[:,a,:] = np.array(data_val['%s'%i].loc[9:19,['x','y','Vx','Vy']])
    in_validation_coord[:,a,:] = np.array(data_val['%s'%i].loc[0:9,['x','y']])
    gt_validation_coord[:,a,:] = np.array(data_val['%s'%i].loc[9:19,['x','y']])
    a +=1


inputs_validation = torch.from_numpy(inputs_validation).float()
gt_validation = torch.from_numpy(gt_validation).float()
inputs_validation = inputs_validation.permute([1,0,2])
gt_validation = gt_validation.permute([1,0,2])

# %%
from torch import optim

lr = 0.01
lstm = LSTM(4*max_len,4)
optimizer = optim.SGD(lstm.parameters(), lr=lr)
criterion = nn.MSELoss()

# %%
traindataset = utils.TensorDataset(inputs_train, gt_train[:,1:,:])
trainloader = utils.DataLoader(traindataset, batch_size=32, shuffle=True)

valdataset = utils.TensorDataset(inputs_validation, gt_validation[:,1:,:])
valloader = utils.DataLoader(valdataset, batch_size=32, shuffle=True)

epochs = 100
steps = 0
print_every = 100
running_loss = 0 #### DOD

for e in range(epochs):
    start = time.time()
    if (e+1)%5==0:
        lr /= 5
        optimizer = optim.SGD(lstm.parameters(), lr=0.005)

    for train_coord, ground_tru in iter(trainloader):
        steps += 1
        
        train_coord = train_coord.permute([1,0,2])
        ground_tru = ground_tru.permute([1,0,2])

        in_train = Variable(train_coord)
        targets = Variable(ground_tru)
        optimizer.zero_grad()
        #print(in_train.shape)
        #print(targets.shape)
        out = lstm.forward(in_train)
        out_bis = out[:,:,0:2].clone()
        #print(out_bis.shape)    
        for i in range(10):
            if i == 0:
                out_bis[i, :, 0:2] = in_train[-1, :, 0:2] + out[i, :, 2:]*0.4
            else:
                out_bis[i, :, 0:2] = out[i - 1, :, 0:2] + out[i, :, 2:]*0.4
        #pdb.set_trace()
        loss1 = (criterion(out[:,:,0:2], targets[:,:,0:2]))
        loss2 = (criterion(out[:,:,2:], targets[:,:,2:]))
        loss3 = criterion(out_bis, targets[:,:,0:2])
                                #+ 10*criterion(out_bis[-1,:,:], targets[-1,:,0:2]) 
                                #+ 10*criterion(out_bis[0,:,:], targets[0,:,0:2]))
        loss1.backward(retain_graph=True)
        loss2.backward(retain_graph=True)
        loss3.backward()
        optimizer.step()
        
        running_loss += (loss1+loss2+loss3).data[0]

    
        if steps % print_every == 0:
                stop = time.time()
                val_loss=0
                for ii, (valcoord, valgt) in enumerate(valloader):
                    inputs = Variable(valcoord, volatile=True)
                    predicted = lstm.predict(inputs)
                    val_loss+= criterion(predicted,valgt).data[0]
                    
                print("Epoch: {}/{}..".format(e+1, epochs),
                  "Validation loss: {:.4f}..".format(val_loss/ii),
                  "Training loss: {:.4f}..".format(running_loss/print_every),
                  "{:.4f} s/batch".format((stop - start)/print_every)
                 )
                running_loss = 0
                start = time.time()
# Out:
# /Users/rodolphefarrando/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:48: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# /Users/rodolphefarrando/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /Users/rodolphefarrando/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# Epoch: 1/100.. Validation loss: 1.1849.. Training loss: 7.2260.. 0.0431 s/batch
# Epoch: 2/100.. Validation loss: 0.9233.. Training loss: 4.3493.. 0.0134 s/batch
# Epoch: 2/100.. Validation loss: 0.8362.. Training loss: 3.4044.. 0.0399 s/batch
# Epoch: 3/100.. Validation loss: 0.7671.. Training loss: 2.9735.. 0.0264 s/batch
# Epoch: 4/100.. Validation loss: 0.7459.. Training loss: 2.8526.. 0.0049 s/batch
# Epoch: 4/100.. Validation loss: 0.7300.. Training loss: 2.6448.. 0.0391 s/batch
# Epoch: 5/100.. Validation loss: 0.7189.. Training loss: 2.6483.. 0.0185 s/batch
# Epoch: 5/100.. Validation loss: 0.7078.. Training loss: 2.5669.. 0.0378 s/batch
# Epoch: 6/100.. Validation loss: 0.7047.. Training loss: 2.5065.. 0.0334 s/batch
# Epoch: 7/100.. Validation loss: 0.7013.. Training loss: 2.5308.. 0.0100 s/batch
# Epoch: 7/100.. Validation loss: 0.6924.. Training loss: 2.4266.. 0.0388 s/batch
# Epoch: 8/100.. Validation loss: 0.6863.. Training loss: 2.4259.. 0.0270 s/batch
# Epoch: 9/100.. Validation loss: 0.6772.. Training loss: 2.3772.. 0.0014 s/batch
# Epoch: 9/100.. Validation loss: 0.6793.. Training loss: 2.3276.. 0.0439 s/batch
# Epoch: 10/100.. Validation loss: 0.6641.. Training loss: 2.3795.. 0.0147 s/batch
# Epoch: 10/100.. Validation loss: 0.6612.. Training loss: 2.2966.. 0.0433 s/batch
# Epoch: 11/100.. Validation loss: 0.6584.. Training loss: 2.2067.. 0.0288 s/batch
# Epoch: 12/100.. Validation loss: 0.6452.. Training loss: 2.2710.. 0.0063 s/batch
# Epoch: 12/100.. Validation loss: 0.6431.. Training loss: 2.2076.. 0.0393 s/batch
# Epoch: 13/100.. Validation loss: 0.6320.. Training loss: 2.2204.. 0.0197 s/batch
# Epoch: 13/100.. Validation loss: 0.6247.. Training loss: 2.1637.. 0.0374 s/batch
# Epoch: 14/100.. Validation loss: 0.6191.. Training loss: 2.1662.. 0.0363 s/batch
# Epoch: 15/100.. Validation loss: 0.6116.. Training loss: 2.0830.. 0.0122 s/batch
# Epoch: 15/100.. Validation loss: 0.6072.. Training loss: 2.0430.. 0.0367 s/batch
# Epoch: 16/100.. Validation loss: 0.5978.. Training loss: 2.0537.. 0.0242 s/batch
# Epoch: 17/100.. Validation loss: 0.5918.. Training loss: 1.9679.. 0.0027 s/batch
# Epoch: 17/100.. Validation loss: 0.5844.. Training loss: 2.0170.. 0.0382 s/batch
# Epoch: 18/100.. Validation loss: 0.5768.. Training loss: 1.9268.. 0.0163 s/batch
# Epoch: 18/100.. Validation loss: 0.5789.. Training loss: 1.9117.. 0.0374 s/batch
# Epoch: 19/100.. Validation loss: 0.5681.. Training loss: 1.8761.. 0.0295 s/batch
# Epoch: 20/100.. Validation loss: 0.5666.. Training loss: 1.8744.. 0.0078 s/batch
# Epoch: 20/100.. Validation loss: 0.5690.. Training loss: 1.8799.. 0.0365 s/batch
# Epoch: 21/100.. Validation loss: 0.5612.. Training loss: 1.7337.. 0.0206 s/batch
# Epoch: 21/100.. Validation loss: 0.5556.. Training loss: 1.8500.. 0.0372 s/batch
# Epoch: 22/100.. Validation loss: 0.5551.. Training loss: 1.7971.. 0.0366 s/batch
# Epoch: 23/100.. Validation loss: 0.5535.. Training loss: 1.7502.. 0.0128 s/batch
# Epoch: 23/100.. Validation loss: 0.5503.. Training loss: 1.7513.. 0.0361 s/batch
# Epoch: 24/100.. Validation loss: 0.5440.. Training loss: 1.7528.. 0.0268 s/batch
# Epoch: 25/100.. Validation loss: 0.5473.. Training loss: 1.6773.. 0.0057 s/batch
# Epoch: 25/100.. Validation loss: 0.5467.. Training loss: 1.6910.. 0.0373 s/batch
# Epoch: 26/100.. Validation loss: 0.5543.. Training loss: 1.6653.. 0.0190 s/batch
# Epoch: 26/100.. Validation loss: 0.5479.. Training loss: 1.6587.. 0.0357 s/batch
# Epoch: 27/100.. Validation loss: 0.5457.. Training loss: 1.6545.. 0.0326 s/batch
# Epoch: 28/100.. Validation loss: 0.5390.. Training loss: 1.6287.. 0.0092 s/batch
# Epoch: 28/100.. Validation loss: 0.5483.. Training loss: 1.6179.. 0.0485 s/batch
# Epoch: 29/100.. Validation loss: 0.5465.. Training loss: 1.6173.. 0.0312 s/batch
# Epoch: 30/100.. Validation loss: 0.5519.. Training loss: 1.6146.. 0.0007 s/batch
# Epoch: 30/100.. Validation loss: 0.5610.. Training loss: 1.5946.. 0.0376 s/batch
# Epoch: 31/100.. Validation loss: 0.5416.. Training loss: 1.6159.. 0.0141 s/batch
# Epoch: 31/100.. Validation loss: 0.5399.. Training loss: 1.5805.. 0.0364 s/batch
# Epoch: 32/100.. Validation loss: 0.5545.. Training loss: 1.5504.. 0.0272 s/batch
# Epoch: 33/100.. Validation loss: 0.5494.. Training loss: 1.5853.. 0.0058 s/batch
# Epoch: 33/100.. Validation loss: 0.5455.. Training loss: 1.5730.. 0.0368 s/batch
# Epoch: 34/100.. Validation loss: 0.5404.. Training loss: 1.5666.. 0.0184 s/batch
# Epoch: 34/100.. Validation loss: 0.5393.. Training loss: 1.5556.. 0.0408 s/batch
# Epoch: 35/100.. Validation loss: 0.5378.. Training loss: 1.5440.. 0.0334 s/batch
# Epoch: 36/100.. Validation loss: 0.5413.. Training loss: 1.5196.. 0.0103 s/batch
# Epoch: 36/100.. Validation loss: 0.5503.. Training loss: 1.5584.. 0.0365 s/batch
# Epoch: 37/100.. Validation loss: 0.5431.. Training loss: 1.5120.. 0.0235 s/batch
# Epoch: 38/100.. Validation loss: 0.5456.. Training loss: 1.5321.. 0.0021 s/batch
# Epoch: 38/100.. Validation loss: 0.5446.. Training loss: 1.5210.. 0.0385 s/batch
# Epoch: 39/100.. Validation loss: 0.5438.. Training loss: 1.5009.. 0.0147 s/batch
# Epoch: 39/100.. Validation loss: 0.5469.. Training loss: 1.5260.. 0.0361 s/batch
# Epoch: 40/100.. Validation loss: 0.5449.. Training loss: 1.4763.. 0.0299 s/batch
# Epoch: 41/100.. Validation loss: 0.5345.. Training loss: 1.5275.. 0.0069 s/batch
# Epoch: 41/100.. Validation loss: 0.5381.. Training loss: 1.5029.. 0.0542 s/batch
# Epoch: 42/100.. Validation loss: 0.5508.. Training loss: 1.5175.. 0.0219 s/batch
# Epoch: 42/100.. Validation loss: 0.5443.. Training loss: 1.4882.. 0.0514 s/batch
# Epoch: 43/100.. Validation loss: 0.5237.. Training loss: 1.5207.. 0.0367 s/batch
# Epoch: 44/100.. Validation loss: 0.5409.. Training loss: 1.5098.. 0.0119 s/batch
# Epoch: 44/100.. Validation loss: 0.5368.. Training loss: 1.4547.. 0.0374 s/batch
# Epoch: 45/100.. Validation loss: 0.5357.. Training loss: 1.4985.. 0.0253 s/batch
# Epoch: 46/100.. Validation loss: 0.5307.. Training loss: 1.4510.. 0.0034 s/batch
# Epoch: 46/100.. Validation loss: 0.5407.. Training loss: 1.4835.. 0.0356 s/batch
# Epoch: 47/100.. Validation loss: 0.5320.. Training loss: 1.4766.. 0.0159 s/batch
# Epoch: 47/100.. Validation loss: 0.5405.. Training loss: 1.4522.. 0.0366 s/batch
# Epoch: 48/100.. Validation loss: 0.5302.. Training loss: 1.4503.. 0.0322 s/batch
# Epoch: 49/100.. Validation loss: 0.5340.. Training loss: 1.4700.. 0.0087 s/batch
# Epoch: 49/100.. Validation loss: 0.5261.. Training loss: 1.4340.. 0.0393 s/batch
# Epoch: 50/100.. Validation loss: 0.5332.. Training loss: 1.4942.. 0.0279 s/batch
# Epoch: 50/100.. Validation loss: 0.5271.. Training loss: 1.4283.. 0.0394 s/batch
# Epoch: 51/100.. Validation loss: 0.5384.. Training loss: 1.4398.. 0.0447 s/batch
# Epoch: 52/100.. Validation loss: 0.5346.. Training loss: 1.4334.. 0.0127 s/batch
# Epoch: 52/100.. Validation loss: 0.5283.. Training loss: 1.4522.. 0.0365 s/batch
# Epoch: 53/100.. Validation loss: 0.5271.. Training loss: 1.4054.. 0.0268 s/batch
# Epoch: 54/100.. Validation loss: 0.5386.. Training loss: 1.4720.. 0.0048 s/batch
# Epoch: 54/100.. Validation loss: 0.5302.. Training loss: 1.3997.. 0.0363 s/batch
# Epoch: 55/100.. Validation loss: 0.5228.. Training loss: 1.4604.. 0.0172 s/batch
# Epoch: 55/100.. Validation loss: 0.5445.. Training loss: 1.4314.. 0.0357 s/batch
# Epoch: 56/100.. Validation loss: 0.5355.. Training loss: 1.4102.. 0.0362 s/batch
# Epoch: 57/100.. Validation loss: 0.5273.. Training loss: 1.4189.. 0.0098 s/batch
# Epoch: 57/100.. Validation loss: 0.5343.. Training loss: 1.3969.. 0.0361 s/batch
# Epoch: 58/100.. Validation loss: 0.5340.. Training loss: 1.4345.. 0.0317 s/batch
# Epoch: 59/100.. Validation loss: 0.5271.. Training loss: 1.4202.. 0.0015 s/batch
# Epoch: 59/100.. Validation loss: 0.5327.. Training loss: 1.4292.. 0.0368 s/batch
# Epoch: 60/100.. Validation loss: 0.5304.. Training loss: 1.4054.. 0.0144 s/batch
# Epoch: 60/100.. Validation loss: 0.5227.. Training loss: 1.4102.. 0.0364 s/batch
# Epoch: 61/100.. Validation loss: 0.5221.. Training loss: 1.4165.. 0.0292 s/batch
# Epoch: 62/100.. Validation loss: 0.5284.. Training loss: 1.3958.. 0.0060 s/batch
# Epoch: 62/100.. Validation loss: 0.5270.. Training loss: 1.4244.. 0.0356 s/batch
# Epoch: 63/100.. Validation loss: 0.5199.. Training loss: 1.3297.. 0.0191 s/batch
# Epoch: 63/100.. Validation loss: 0.5265.. Training loss: 1.4212.. 0.0361 s/batch
# Epoch: 64/100.. Validation loss: 0.5212.. Training loss: 1.4023.. 0.0337 s/batch
# Epoch: 65/100.. Validation loss: 0.5367.. Training loss: 1.4032.. 0.0110 s/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-f5be3fccb83c> in <module>()
#      43         loss1.backward(retain_graph=True)
#      44         loss2.backward(retain_graph=True)
# ---> 45         loss3.backward()
#      46         optimizer.step()
#      47
#
# ~/anaconda3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
inputs_pred = inputs_train.permute([1,0,2])
output_final = lstm.predict(inputs_pred)
output_final = output_final.data.numpy()

# %% [markdown]
# ## Post processing step
# Go back to coordinate:
# We have Vx and Vy and we want x and y.
# $ V = d/t$
# $ d = V*t$
# Here t = 0.4s between each point.
# Start from data at index 9. Then we add d_x and d_y to the last x and y.

# %%
output_final.shape
# Out:
# (10, 5157, 4)

# %%
output_coord=np.zeros([11,len(data_train),2])
for j in range(11):
    for i in range(len(data_train)):
        if j==0:
            output_coord[j,i,0:2] = in_train_coord[9,i,0:2]
        else:
            output_coord[j,i,0:2] = output_coord[j-1,i,0:2]+output_final[j-1,i,2:]*0.4

# %%
for i in range(20):
    plt.figure(figsize=(12, 7))

    plt.plot(in_train_coord[:,(i*20)+2000,0],in_train_coord[:,i*20+2000,1],c='b')
    plt.plot(gt_train_coord[:,i*20+2000,0],gt_train_coord[:,i*20+2000,1],c='k')
    plt.plot(output_coord[:,i*20+2000,0],output_coord[:,i*20+2000,1],c='r')
    plt.axis('equal')

# %%
sum(sum(sum(inputs_train>0)))

# %%
inputs_train.shape

# %%
4*max_len
