# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from myclass.Representation import *
from myclass.Training import *

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

# For the notebook
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os
data = {}
a=0
for j in range(1,4):
    for i in os.listdir('./data_linear_augm/%s'%j):
        if i.endswith('.txt'):
            a = a+1
            data[a] = Training('./data_linear_augm/{}/{}'.format(j,i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-3a78858d253b> in <module>()
#       6         if i.endswith('.txt'):
#       7             a = a+1
# ----> 8             data[a] = Training('./data_linear_augm/{}/{}'.format(j,i))
#
# ~/Documents/EPFL/Master/MA4/DAIT/Trajectory-Prediciton-DAIT/myclass/Training.py in __init__(self, path)
#      11
#      12     def __init__(self,path):
# ---> 13         self.data = pd.read_csv(path, header = None, names = ['frameNb','id', 'x','y','Vx','Vy'],delimiter=' ')
#      14         for i in range(len(path) - 1, -1, -1):
#      15             if path[i] == '/':
#
# NameError: name 'pd' is not defined

# %%
for i in range(1,len(data)+1):
    data[i].flip()

# %%
data['%s'%(len(data))].data
# Out:
#     frameNb   id         x         y        Vx        Vy
# 0       120   96  0.000000  0.000000  0.000000  0.000000
# 1       122   96 -0.000000  0.080623 -0.000000  0.201556
# 2       124   96 -0.000000  0.080623  0.000000  0.000000
# 3       126   96 -0.000000  0.080623  0.000000  0.000000
# 4       128   96 -0.000000  0.080623  0.000000  0.000000
# 5       130   96 -0.000000  0.080623  0.000000  0.000000
# 6       132   96 -0.000000  0.161245 -0.000000  0.201556
# 7       134   96 -0.000000  0.161245  0.000000  0.000000
# 8       136   96 -0.000000  0.161245  0.000000  0.000000
# 9       138   96 -0.022326  0.243108 -0.055816  0.204657
# 10      140   96 -0.066979  0.245589 -0.111631  0.006202
# 11      142   96 -0.089305  0.327452 -0.055816  0.204657
# 12      144   96 -0.156284  0.411795 -0.167447  0.210859
# 13      146   96 -0.200936  0.494899 -0.111631  0.207758
# 14      148   96 -0.259233  0.816149 -0.145741  0.803125
# 15      150   96 -0.344817  1.049334 -0.213960  0.582963
# 16      152   96 -0.452727  1.283759 -0.269776  0.586064
# 17      154   96 -0.529628  1.592606 -0.192254  0.772116
# 18      156   96 -0.673509  1.743928 -0.359701  0.378306
# 19      158   96 -0.829792  1.833233 -0.390709  0.223263
# 20      114   98 -6.082663  4.270516  0.000000  0.000000
# 21      116   98 -5.928860  4.136558  0.384508 -0.334894
# 22      118   98 -5.752731  4.001361  0.440323 -0.337995
# 23      120   98 -5.433962  3.853759  0.796923 -0.369003
# 24      122   98 -5.099068  3.512664  0.837234 -0.852739
# 25      124   98 -4.729444  3.232345  0.924059 -0.700796
# 26      126   98 -4.395791  2.949546  0.834134 -0.706998
# 27      128   98 -4.054695  2.720082  0.852739 -0.573661
# 28      130   98 -3.784300  2.427360  0.675989 -0.731805
# 29      132   98 -3.510183  2.201617  0.685292 -0.564358
# ..      ...  ...       ...       ...       ...       ...
# 50      140   52  0.703277  0.726844 -0.055816  0.204657
# 51      142   52  0.698316  0.879406 -0.012403  0.381407
# 52      144   52  0.675989  0.961269 -0.055816  0.204657
# 53      146   52  0.675989  1.041892 -0.000000  0.201556
# 54      148   52  0.635058  1.191974 -0.102329  0.375205
# 55      150   52  0.496139  1.351979 -0.347297  0.400012
# 56      152   52  0.347297  1.655864 -0.372104  0.759713
# 57      154   52  0.198456  1.879126 -0.372104  0.558156
# 58      156   52  0.037210  2.040371 -0.403113  0.403113
# 59      158   52 -0.107910  2.330613 -0.362802  0.725603
# 60      134  100 -5.435202  6.169488  0.000000  0.000000
# 61      136  100 -5.251631  6.007002  0.458929 -0.406214
# 62      138  100 -5.001080  5.840796  0.626375 -0.415516
# 63      140  100 -4.748050  5.557996  0.632577 -0.706998
# 64      142  100 -4.456568  5.322330  0.728704 -0.589165
# 65      144  100 -4.178730  5.082943  0.694595 -0.598468
# 66      146  100 -3.878566  4.842316  0.750410 -0.601568
# 67      148  100 -3.592046  4.597968  0.716301 -0.610871
# 68      150  100 -3.274517  4.347417  0.793822 -0.626375
# 69      152  100 -2.997920  4.085704  0.691494 -0.654283
# 70      154  100 -2.700236  3.881047  0.744208 -0.511643
# 71      156  100 -2.422398  3.802905  0.694595 -0.195355
# 72      158  100 -2.148282  3.657784  0.685292 -0.362802
# 73      160  100 -1.870444  3.579642  0.694595 -0.195355
# 74      162  100 -1.588885  3.487857  0.703897 -0.229464
# 75      164  100 -1.311047  3.409715  0.694595 -0.195355
# 76      166  100 -1.024527  3.326612  0.716301 -0.207758
# 77      168  100 -0.733045  3.171568  0.728704 -0.387609
# 78      170  100 -0.427920  3.020246  0.762814 -0.378306
# 79      172  100 -0.132717  2.932181  0.738007 -0.220162
#
# [80 rows x 6 columns]
